# %% [markdown]
# ## Library imports + importing dataset

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv("IMDb_Dataset_Edited.csv")

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# # Sample of dataset

# %%
df.sample(3)
# Out:
#             id                                           title  vote_average  \
# 39618   858461                           Night of the Jarrawog           0.0
# 29244  1017100                                         Saguaro           0.0
# 16623  1172426  The Harvest: Integrating Mississippi's Schools           0.0
#
#        vote_count    status release_date  revenue  runtime  adult  budget  \
# 39618           0  Released    27/3/2021        0       14  False       0
# 29244           0  Released   16/12/2022        0       90  False      90
# 16623           0  Released    12/9/2023        0      113  False       0
#
#           imdb_id original_language  \
# 39618  tt14349590                en
# 29244         NaN                en
# 16623         NaN                en
#
#                                        original_title  \
# 39618                           Night of the Jarrawog
# 29244                                         Saguaro
# 16623  The Harvest: Integrating Mississippi's Schools
#
#                                                 overview  popularity  \
# 39618  A pizza boy on his rounds becomes embroiled in...       0.600
# 29244  Paul, a teenager in Arizona, tries to repair h...       0.600
# 16623  In The Harvest, Pulitzer Prize-winning author ...       3.898
#
#                                        tagline  \
# 39618                                      NaN
# 29244                              Movinâ€™ on
# 16623  Planting seeds one classroom at a time.
#
#                                     production_companies  \
# 39618                                                NaN
# 29244                                                NaN
# 16623  American Experience Films, Five Dollar Films, ...
#
#            production_countries spoken_languages keywords  release_year  \
# 39618                 Australia          English       []          2021
# 29244  United States of America              NaN       []          2022
# 16623  United States of America          English       []          2023
#
#                                   Director  AverageRating Poster_Link  \
# 39618        TomÃ¡s Raimondo, Iara Udijara            NaN         NaN
# 29244                    Ã‰douard Molinaro            NaN         NaN
# 16623  Anton Chystiakov, Roman Krasnoschok            NaN         NaN
#
#       Certificate  IMDB_Rating  Meta_score Star1 Star2 Star3 Star4  \
# 39618         NaN          NaN         NaN   NaN   NaN   NaN   NaN
# 29244         NaN          NaN         NaN   NaN   NaN   NaN   NaN
# 16623         NaN          NaN         NaN   NaN   NaN   NaN   NaN
#
#                                                   Writer  \
# 39618  TomÃ¡s Niro Chame, Melina Remonda, TomÃ¡s Raim...
# 29244                                       AndrÃ© Tabet
# 16623                                  Roman Krasnoschok
#
#                  Director_of_Photography         Producers Music_Composer  \
# 39618  Melina Remonda, TomÃ¡s Niro Chame               NaN            NaN
# 29244                                NaN      Michel Ardan  Martial Solal
# 16623                                NaN  Anna Pozdnyakova            NaN
#
#                       genres_list  \
# 39618        ['Horror', 'Comedy']
# 29244                   ['Drama']
# 16623  ['Documentary', 'History']
#
#                                                Cast_list  overview_sentiment  \
# 39618                                        ['Unknown']            0.000000
# 29244  ['Pascale Audrey', 'Jacques Monod', 'Claude Ch...           -0.100000
# 16623  ['Larysa Rusnak', 'Rymma Zyubina', 'Yevhenii L...            0.061759
#
#                                    all_combined_keywords
# 39618  ['customer â€™ s monster hunt', 's', 'hunt', '...
# 29244  ['paul', 'oregon', 'relationships', 'end', 'mo...
# 16623  ['douglas', 'white children', 'winning', 'sout...

# %% [markdown]
# # Dataset info with df.info()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89538 entries, 0 to 89537
# Data columns (total 39 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       89538 non-null  int64
#  1   title                    89538 non-null  object
#  2   vote_average             89538 non-null  float64
#  3   vote_count               89538 non-null  int64
#  4   status                   89538 non-null  object
#  5   release_date             89538 non-null  object
#  6   revenue                  89538 non-null  int64
#  7   runtime                  89538 non-null  int64
#  8   adult                    89538 non-null  bool
#  9   budget                   89538 non-null  int64
#  10  imdb_id                  40169 non-null  object
#  11  original_language        89538 non-null  object
#  12  original_title           89538 non-null  object
#  13  overview                 85545 non-null  object
#  14  popularity               89538 non-null  float64
#  15  tagline                  21199 non-null  object
#  16  production_companies     39255 non-null  object
#  17  production_countries     43045 non-null  object
#  18  spoken_languages         45698 non-null  object
#  19  keywords                 89538 non-null  object
#  20  release_year             89538 non-null  int64
#  21  Director                 89538 non-null  object
#  22  AverageRating            1118 non-null   float64
#  23  Poster_Link              174 non-null    object
#  24  Certificate              2566 non-null   object
#  25  IMDB_Rating              2596 non-null   float64
#  26  Meta_score               145 non-null    float64
#  27  Star1                    2596 non-null   object
#  28  Star2                    174 non-null    object
#  29  Star3                    174 non-null    object
#  30  Star4                    174 non-null    object
#  31  Writer                   53758 non-null  object
#  32  Director_of_Photography  27886 non-null  object
#  33  Producers                35010 non-null  object
#  34  Music_Composer           12716 non-null  object
#  35  genres_list              89538 non-null  object
#  36  Cast_list                89538 non-null  object
#  37  overview_sentiment       89538 non-null  float64
#  38  all_combined_keywords    89538 non-null  object
# dtypes: bool(1), float64(6), int64(6), object(26)
# memory usage: 26.0+ MB
